# %% [markdown]
# # This code uses COVID 19 data for visualization of total number of cases in a country and display an interactive world map. User can move the cursor on the map to find out the cases in a specific country. This data presents total number of cases on August 25, 2020

# %% [markdown]
# First of all, I will install pyecharts library.

# %%
#install pyecharts

pip install pyecharts==1.7.1
# Out:
# Collecting pyecharts==1.7.1
#   Downloading pyecharts-1.7.1-py3-none-any.whl (128 kB)
# Collecting simplejson
#   Downloading simplejson-3.17.2.tar.gz (83 kB)
# Collecting prettytable
#   Downloading prettytable-0.7.2.tar.bz2 (21 kB)
# Requirement already satisfied: jinja2 in c:\users\asad\anaconda3\lib\site-packages (from pyecharts==1.7.1) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\asad\anaconda3\lib\site-packages (from jinja2->pyecharts==1.7.1) (1.1.1)
# Building wheels for collected packages: simplejson, prettytable
#   Building wheel for simplejson (setup.py): started
#   Building wheel for simplejson (setup.py): finished with status 'done'
#   Created wheel for simplejson: filename=simplejson-3.17.2-py3-none-any.whl size=55464 sha256=7ca9e75eb2eafac909a4e6c91e3adb2d9812b2f2ec757799b0c75427788ba81b
#   Stored in directory: c:\users\asad\appdata\local\pip\cache\wheels\17\72\7d\df0984c925921e22322ea462a6f861e9d0617881192deb9b8d
#   Building wheel for prettytable (setup.py): started
#   Building wheel for prettytable (setup.py): finished with status 'done'
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13704 sha256=55b87c760bed5863db4fb666030c116df742aa11b9b2173cf604783cb908637a
#   Stored in directory: c:\users\asad\appdata\local\pip\cache\wheels\46\60\6c\bb25d05df22906786206e901e9354bb3061061191116768bee
# Successfully built simplejson prettytable
# Installing collected packages: simplejson, prettytable, pyecharts
# Successfully installed prettytable-0.7.2 pyecharts-1.7.1 simplejson-3.17.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import all the libraries to be used

# %%
#import libraries
from pyecharts.charts import Map,Geo
from pyecharts import options as opts
from pyecharts.globals import ThemeType
import numpy as np
import pandas as pd
import xlsxwriter

# %% [markdown]
# # Import data set: The data was downloaded from https://ourworldindata.org/coronavirus

# %%
#import data

dataset = pd.read_excel (r'C:\Users\Asad\Downloads\owid-covid-data.xlsx')
print (dataset)
# Out:
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  2020-03-13          2.0
# 1          ABW  North America          Aruba  2020-03-19          NaN
# 2          ABW  North America          Aruba  2020-03-20          4.0
# 3          ABW  North America          Aruba  2020-03-21          NaN
# 4          ABW  North America          Aruba  2020-03-22          NaN
# ...        ...            ...            ...         ...          ...
# 39477      NaN            NaN  International  2020-08-21        696.0
# 39478      NaN            NaN  International  2020-08-22        696.0
# 39479      NaN            NaN  International  2020-08-23        696.0
# 39480      NaN            NaN  International  2020-08-24        696.0
# 39481      NaN            NaN  International  2020-08-25        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            2.0                 NaN           0.0         0.0
# 1            NaN               0.286           NaN         NaN
# 2            2.0               0.286           0.0         0.0
# 3            NaN               0.286           NaN         NaN
# 4            NaN               0.286           NaN         NaN
# ...          ...                 ...           ...         ...
# 39477        NaN                 NaN           7.0         NaN
# 39478        NaN                 NaN           7.0         NaN
# 39479        NaN                 NaN           7.0         NaN
# 39480        NaN                 NaN           7.0         NaN
# 39481        NaN                 NaN           7.0         NaN
#
#        new_deaths_smoothed  ...  aged_70_older  gdp_per_capita  \
# 0                      NaN  ...          7.452       35973.781
# 1                      0.0  ...          7.452       35973.781
# 2                      0.0  ...          7.452       35973.781
# 3                      0.0  ...          7.452       35973.781
# 4                      0.0  ...          7.452       35973.781
# ...                    ...  ...            ...             ...
# 39477                  NaN  ...            NaN             NaN
# 39478                  NaN  ...            NaN             NaN
# 39479                  NaN  ...            NaN             NaN
# 39480                  NaN  ...            NaN             NaN
# 39481                  NaN  ...            NaN             NaN
#
#        extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# 0                  NaN                    NaN                11.62
# 1                  NaN                    NaN                11.62
# 2                  NaN                    NaN                11.62
# 3                  NaN                    NaN                11.62
# 4                  NaN                    NaN                11.62
# ...                ...                    ...                  ...
# 39477              NaN                    NaN                  NaN
# 39478              NaN                    NaN                  NaN
# 39479              NaN                    NaN                  NaN
# 39480              NaN                    NaN                  NaN
# 39481              NaN                    NaN                  NaN
#
#        female_smokers  male_smokers  handwashing_facilities  \
# 0                 NaN           NaN                     NaN
# 1                 NaN           NaN                     NaN
# 2                 NaN           NaN                     NaN
# 3                 NaN           NaN                     NaN
# 4                 NaN           NaN                     NaN
# ...               ...           ...                     ...
# 39477             NaN           NaN                     NaN
# 39478             NaN           NaN                     NaN
# 39479             NaN           NaN                     NaN
# 39480             NaN           NaN                     NaN
# 39481             NaN           NaN                     NaN
#
#        hospital_beds_per_thousand  life_expectancy
# 0                             NaN            76.29
# 1                             NaN            76.29
# 2                             NaN            76.29
# 3                             NaN            76.29
# 4                             NaN            76.29
# ...                           ...              ...
# 39477                         NaN              NaN
# 39478                         NaN              NaN
# 39479                         NaN              NaN
# 39480                         NaN              NaN
# 39481                         NaN              NaN
#
# [39482 rows x 40 columns]

# %% [markdown]
# # Data needs to be cleaned before further processing

# %%
#Sort data type and pick a particlular date
dataset["date"]=pd.to_datetime(dataset["date"])
df = dataset.sort_values(by=['date'], ascending=False) #sort data by date
map_df=df[df['date']=='2020-08-25']
map_df.reset_index(drop=True, inplace=True)
map_df
# Out:
#     iso_code      continent                          location       date  \
# 0        NaN            NaN                     International 2020-08-25
# 1        MLI         Africa                              Mali 2020-08-25
# 2        COD         Africa      Democratic Republic of Congo 2020-08-25
# 3        NER         Africa                             Niger 2020-08-25
# 4        GHA         Africa                             Ghana 2020-08-25
# ..       ...            ...                               ...        ...
# 205      UZB           Asia                        Uzbekistan 2020-08-25
# 206      SXM  North America         Sint Maarten (Dutch part) 2020-08-25
# 207      VCT  North America  Saint Vincent and the Grenadines 2020-08-25
# 208      BHR           Asia                           Bahrain 2020-08-25
# 209      YEM           Asia                             Yemen 2020-08-25
#
#      total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0          696.0        NaN                 NaN           7.0         NaN
# 1         2708.0        3.0               9.714         125.0         0.0
# 2         9841.0       12.0              19.429         250.0         0.0
# 3         1172.0        0.0               0.714          69.0         0.0
# 4        43622.0      117.0             138.429         263.0         2.0
# ..           ...        ...                 ...           ...         ...
# 205      39506.0      560.0             486.571         282.0         9.0
# 206        408.0       12.0              11.714          17.0         0.0
# 207         58.0        0.0               0.000           0.0         0.0
# 208      49330.0      292.0             306.429         184.0         0.0
# 209       1916.0        5.0               4.857         555.0         8.0
#
#      new_deaths_smoothed  ...  aged_70_older  gdp_per_capita  extreme_poverty  \
# 0                    NaN  ...            NaN             NaN              NaN
# 1                  0.000  ...          1.486        2014.306              NaN
# 2                  1.143  ...          1.745         808.133             77.1
# 3                  0.000  ...          1.378         926.000             44.5
# 4                  3.429  ...          1.948        4227.630             12.0
# ..                   ...  ...            ...             ...              ...
# 205                6.000  ...          2.873        6253.104              NaN
# 206                0.000  ...            NaN       36327.232              NaN
# 207                0.000  ...          4.832       10727.146              NaN
# 208                1.571  ...          1.387       43290.705              NaN
# 209                2.857  ...          1.583        1479.147             18.8
#
#      cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 0                      NaN                  NaN             NaN           NaN
# 1                  268.024                 2.42             1.6          23.0
# 2                  318.949                 6.10             NaN           NaN
# 3                  238.339                 2.42             0.1          15.4
# 4                  298.245                 4.97             0.3           7.7
# ..                     ...                  ...             ...           ...
# 205                724.417                 7.57             1.3          24.7
# 206                    NaN                  NaN             NaN           NaN
# 207                252.675                11.62             NaN           NaN
# 208                151.689                16.52             5.8          37.6
# 209                495.003                 5.35             7.6          29.2
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy
# 0                       NaN                         NaN              NaN
# 1                    52.232                         0.1            59.31
# 2                     4.472                         NaN            60.68
# 3                     8.978                         0.3            62.42
# 4                    41.047                         0.9            64.07
# ..                      ...                         ...              ...
# 205                     NaN                         4.0            71.72
# 206                     NaN                         NaN            78.95
# 207                     NaN                         2.6            72.53
# 208                     NaN                         2.0            77.29
# 209                  49.542                         0.7            66.12
#
# [210 rows x 40 columns]

# %% [markdown]
# # Adding total number of cases per country on world's map

# %%
country=list(map_df["location"])
totalcases=list(map_df["total_cases"])

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))] #prepare data for visualization
map_1 = Map(init_opts=opts.InitOpts(width='1000px', height='460px')) #create the map and set the size of the map
map_1.add("Total Confirmed Cases", list1, maptype='world') #add world map
map_1.set_global_opts( #set global config
 visualmap_opts=opts.VisualMapOpts(max_=1100000,    is_piecewise=False),
 legend_opts=opts.LegendOpts(is_show=False), #show legend 
 )
map_1.render_notebook() #show the map
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="b93c057106a84eaa8c51448b02163291" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_b93c057106a84eaa8c51448b02163291 = echarts.init(
#                     document.getElementById('b93c057106a84eaa8c51448b02163291'), 'white', {renderer: 'canvas'});
#                 var option_b93c057106a84eaa8c51448b02163291 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Cases",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "International",
#                     "value": 696.0
#                 },
#                 {
#                     "name": "Mali",
#                     "value": 2708.0
#                 },
#                 {
#                     "name": "Democratic Republic of Congo",
#                     "value": 9841.0
#                 },
#                 {
#                     "name": "Niger",
#                     "value": 1172.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 43622.0
#                 },
#                 {
#                     "name": "Nicaragua",
#                     "value": 4311.0
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 67062.0
#                 },
#                 {
#                     "name": "Albania",
#                     "value": 8605.0
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 18762.0
#                 },
#                 {
#                     "name": "Norway",
#                     "value": 10323.0
#                 },
#                 {
#                     "name": "Nepal",
#                     "value": 32678.0
#                 },
#                 {
#                     "name": "Cote d'Ivoire",
#                     "value": 17506.0
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 1339.0
#                 },
#                 {
#                     "name": "Oman",
#                     "value": 84509.0
#                 },
#                 {
#                     "name": "China",
#                     "value": 89718.0
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 293711.0
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 87485.0
#                 },
#                 {
#                     "name": "Chile",
#                     "value": 399568.0
#                 },
#                 {
#                     "name": "Peru",
#                     "value": 600438.0
#                 },
#                 {
#                     "name": "New Caledonia",
#                     "value": 23.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 6030.0
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 3850.0
#                 },
#                 {
#                     "name": "Afghanistan",
#                     "value": 38070.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 1667.0
#                 },
#                 {
#                     "name": "Myanmar",
#                     "value": 474.0
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 3717.0
#                 },
#                 {
#                     "name": "Montenegro",
#                     "value": 4378.0
#                 },
#                 {
#                     "name": "Mongolia",
#                     "value": 298.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 34463.0
#                 },
#                 {
#                     "name": "Northern Mariana Islands",
#                     "value": 54.0
#                 },
#                 {
#                     "name": "Cape Verde",
#                     "value": 3532.0
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 9274.0
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value": 3440.0
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 6905.0
#                 },
#                 {
#                     "name": "Comoros",
#                     "value": 417.0
#                 },
#                 {
#                     "name": "Montserrat",
#                     "value": 13.0
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 346.0
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 551696.0
#                 },
#                 {
#                     "name": "Malawi",
#                     "value": 5419.0
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 194252.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 39959.0
#                 },
#                 {
#                     "name": "Papua New Guinea",
#                     "value": 401.0
#                 },
#                 {
#                     "name": "Belize",
#                     "value": 713.0
#                 },
#                 {
#                     "name": "Sierra Leone",
#                     "value": 1997.0
#                 },
#                 {
#                     "name": "Bolivia",
#                     "value": 110148.0
#                 },
#                 {
#                     "name": "El Salvador",
#                     "value": 24811.0
#                 },
#                 {
#                     "name": "San Marino",
#                     "value": 726.0
#                 },
#                 {
#                     "name": "Bermuda",
#                     "value": 168.0
#                 },
#                 {
#                     "name": "Somalia",
#                     "value": 3269.0
#                 },
#                 {
#                     "name": "Serbia",
#                     "value": 30714.0
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 2504.0
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 3622861.0
#                 },
#                 {
#                     "name": "Sao Tome and Principe",
#                     "value": 892.0
#                 },
#                 {
#                     "name": "Belarus",
#                     "value": 70645.0
#                 },
#                 {
#                     "name": "Suriname",
#                     "value": 3632.0
#                 },
#                 {
#                     "name": "Slovakia",
#                     "v

# %% [markdown]
# # A total of 212 countries displayed on map. The data looks clumsy. We can get rid of countries name to make it more attaractive

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))] 
map_1 = Map(init_opts=opts.InitOpts(width='1000px', height='460px')) 
map_1.add("Total Confirmed Cases", 
 list1, maptype='world') 
map_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False)) #remove country names
map_1.set_global_opts(visualmap_opts=opts.VisualMapOpts(max_=1100000,is_piecewise=False),
 legend_opts=opts.LegendOpts(is_show=False))
map_1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="39e9f10ad4794395ab2f4ce6ce7f5f74" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_39e9f10ad4794395ab2f4ce6ce7f5f74 = echarts.init(
#                     document.getElementById('39e9f10ad4794395ab2f4ce6ce7f5f74'), 'white', {renderer: 'canvas'});
#                 var option_39e9f10ad4794395ab2f4ce6ce7f5f74 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "International",
#                     "value": 696.0
#                 },
#                 {
#                     "name": "Mali",
#                     "value": 2708.0
#                 },
#                 {
#                     "name": "Democratic Republic of Congo",
#                     "value": 9841.0
#                 },
#                 {
#                     "name": "Niger",
#                     "value": 1172.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 43622.0
#                 },
#                 {
#                     "name": "Nicaragua",
#                     "value": 4311.0
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 67062.0
#                 },
#                 {
#                     "name": "Albania",
#                     "value": 8605.0
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 18762.0
#                 },
#                 {
#                     "name": "Norway",
#                     "value": 10323.0
#                 },
#                 {
#                     "name": "Nepal",
#                     "value": 32678.0
#                 },
#                 {
#                     "name": "Cote d'Ivoire",
#                     "value": 17506.0
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 1339.0
#                 },
#                 {
#                     "name": "Oman",
#                     "value": 84509.0
#                 },
#                 {
#                     "name": "China",
#                     "value": 89718.0
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 293711.0
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 87485.0
#                 },
#                 {
#                     "name": "Chile",
#                     "value": 399568.0
#                 },
#                 {
#                     "name": "Peru",
#                     "value": 600438.0
#                 },
#                 {
#                     "name": "New Caledonia",
#                     "value": 23.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 6030.0
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 3850.0
#                 },
#                 {
#                     "name": "Afghanistan",
#                     "value": 38070.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 1667.0
#                 },
#                 {
#                     "name": "Myanmar",
#                     "value": 474.0
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 3717.0
#                 },
#                 {
#                     "name": "Montenegro",
#                     "value": 4378.0
#                 },
#                 {
#                     "name": "Mongolia",
#                     "value": 298.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 34463.0
#                 },
#                 {
#                     "name": "Northern Mariana Islands",
#                     "value": 54.0
#                 },
#                 {
#                     "name": "Cape Verde",
#                     "value": 3532.0
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 9274.0
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value": 3440.0
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 6905.0
#                 },
#                 {
#                     "name": "Comoros",
#                     "value": 417.0
#                 },
#                 {
#                     "name": "Montserrat",
#                     "value": 13.0
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 346.0
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 551696.0
#                 },
#                 {
#                     "name": "Malawi",
#                     "value": 5419.0
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 194252.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 39959.0
#                 },
#                 {
#                     "name": "Papua New Guinea",
#                     "value": 401.0
#                 },
#                 {
#                     "name": "Belize",
#                     "value": 713.0
#                 },
#                 {
#                     "name": "Sierra Leone",
#                     "value": 1997.0
#                 },
#                 {
#                     "name": "Bolivia",
#                     "value": 110148.0
#                 },
#                 {
#                     "name": "El Salvador",
#                     "value": 24811.0
#                 },
#                 {
#                     "name": "San Marino",
#                     "value": 726.0
#                 },
#                 {
#                     "name": "Bermuda",
#                     "value": 168.0
#                 },
#                 {
#                     "name": "Somalia",
#                     "value": 3269.0
#                 },
#                 {
#                     "name": "Serbia",
#                     "value": 30714.0
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 2504.0
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 3622861.0
#                 },
#                 {
#                     "name": "Sao Tome and Principe",
#                     "value": 892.0
#                 },
#                 {
#                     "name": "Belarus",
#                     "value": 70645.0
#                 },
#                 {
#                     "name": "Suriname",
#                     "value": 3632.0
#                 },
#                 {
#                     "name": "Slovakia",
#                     "

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))] 
map_1 = Map(init_opts=opts.InitOpts(width='1000px', height='460px')) 
map_1.add("Total Confirmed Cases", 
 list1, 
 maptype='world',
 is_map_symbol_show=False)
map_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False)) 
map_1.set_global_opts(visualmap_opts=opts.VisualMapOpts(max_=1100000,is_piecewise=False),
 legend_opts=opts.LegendOpts(is_show=False))
map_1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="dc365997ad404e2e8849c450150e97af" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_dc365997ad404e2e8849c450150e97af = echarts.init(
#                     document.getElementById('dc365997ad404e2e8849c450150e97af'), 'white', {renderer: 'canvas'});
#                 var option_dc365997ad404e2e8849c450150e97af = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "International",
#                     "value": 696.0
#                 },
#                 {
#                     "name": "Mali",
#                     "value": 2708.0
#                 },
#                 {
#                     "name": "Democratic Republic of Congo",
#                     "value": 9841.0
#                 },
#                 {
#                     "name": "Niger",
#                     "value": 1172.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 43622.0
#                 },
#                 {
#                     "name": "Nicaragua",
#                     "value": 4311.0
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 67062.0
#                 },
#                 {
#                     "name": "Albania",
#                     "value": 8605.0
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 18762.0
#                 },
#                 {
#                     "name": "Norway",
#                     "value": 10323.0
#                 },
#                 {
#                     "name": "Nepal",
#                     "value": 32678.0
#                 },
#                 {
#                     "name": "Cote d'Ivoire",
#                     "value": 17506.0
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 1339.0
#                 },
#                 {
#                     "name": "Oman",
#                     "value": 84509.0
#                 },
#                 {
#                     "name": "China",
#                     "value": 89718.0
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 293711.0
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 87485.0
#                 },
#                 {
#                     "name": "Chile",
#                     "value": 399568.0
#                 },
#                 {
#                     "name": "Peru",
#                     "value": 600438.0
#                 },
#                 {
#                     "name": "New Caledonia",
#                     "value": 23.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 6030.0
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 3850.0
#                 },
#                 {
#                     "name": "Afghanistan",
#                     "value": 38070.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 1667.0
#                 },
#                 {
#                     "name": "Myanmar",
#                     "value": 474.0
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 3717.0
#                 },
#                 {
#                     "name": "Montenegro",
#                     "value": 4378.0
#                 },
#                 {
#                     "name": "Mongolia",
#                     "value": 298.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 34463.0
#                 },
#                 {
#                     "name": "Northern Mariana Islands",
#                     "value": 54.0
#                 },
#                 {
#                     "name": "Cape Verde",
#                     "value": 3532.0
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 9274.0
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value": 3440.0
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 6905.0
#                 },
#                 {
#                     "name": "Comoros",
#                     "value": 417.0
#                 },
#                 {
#                     "name": "Montserrat",
#                     "value": 13.0
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 346.0
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 551696.0
#                 },
#                 {
#                     "name": "Malawi",
#                     "value": 5419.0
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 194252.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 39959.0
#                 },
#                 {
#                     "name": "Papua New Guinea",
#                     "value": 401.0
#                 },
#                 {
#                     "name": "Belize",
#                     "value": 713.0
#                 },
#                 {
#                     "name": "Sierra Leone",
#                     "value": 1997.0
#                 },
#                 {
#                     "name": "Bolivia",
#                     "value": 110148.0
#                 },
#                 {
#                     "name": "El Salvador",
#                     "value": 24811.0
#                 },
#                 {
#                     "name": "San Marino",
#                     "value": 726.0
#                 },
#                 {
#                     "name": "Bermuda",
#                     "value": 168.0
#                 },
#                 {
#                     "name": "Somalia",
#                     "value": 3269.0
#                 },
#                 {
#                     "name": "Serbia",
#                     "value": 30714.0
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 2504.0
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 3622861.0
#                 },
#                 {
#                     "name": "Sao Tome and Principe",
#                     "value": 892.0
#                 },
#                 {
#                     "name": "Belarus",
#                     "value": 70645.0
#                 },
#                 {
#                     "name": "Suriname",
#                     "value": 3632.0
#                 },
#                 {
#                     "name": "Slovakia",
#                     "

# %% [markdown]
# # Let's organize the data with a color map by adding limits on number of cases.

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))] 
map_1 = Map(init_opts=opts.InitOpts(width='1000px', height='460px')) 
map_1.add("Total Confirmed Cases", 
 list1, 
 maptype='world',
 is_map_symbol_show=False) 
map_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False)) 
map_1.set_global_opts(visualmap_opts=opts.VisualMapOpts(max_=50000000,is_piecewise=True,pieces=[
 {"min": 900000},
 {"min": 200000, "max": 499999},
 {"min": 100000, "max": 199999},
 {"min": 50000, "max": 99999},
 {"min": 10000, "max": 49999},
 {"max": 9999},]),
 legend_opts=opts.LegendOpts(is_show=False))
map_1.render_notebook()

# %% [markdown]
# # We can add a title of on the interactive map with a date when the data was processed

# %%
list1 = [[country[i],totalcases[i]] for i in range(len(country))] 
map_1 = Map(init_opts=opts.InitOpts(width='1000px', height='460px')) 
map_1.add('Total Confirmed Cases', 
 list1,
 maptype='world',
 is_map_symbol_show=False)
map_1.set_series_opts(label_opts=opts.LabelOpts(is_show=False)) 
map_1.set_global_opts(
visualmap_opts=opts.VisualMapOpts(max_=1100000,is_piecewise=True,pieces=[
 {"min": 500000},
 {"min": 200000, "max": 499999},
 {"min": 100000, "max": 199999},
 {"min": 50000, "max": 99999},
 {"min": 10000, "max": 49999},
 {"max": 9999},]),
 title_opts=opts.TitleOpts(
 title='Covid-19 Worldwide Total Cases',
 subtitle='Till Aug 25th,2020',
 pos_left='center',
 padding=0,
 item_gap=2,# gap between title and subtitle 
 title_textstyle_opts= opts.TextStyleOpts(color='magenta',
 font_weight='bold',
 font_family='Courier New',
 font_size=30), 
 subtitle_textstyle_opts= opts.TextStyleOpts(color='grey',
 font_weight='bold',
 font_family='Courier New',
 font_size=13)), 
 legend_opts=opts.LegendOpts(is_show=False))
map_1.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="79172abb53b94d9eaa81ef4654f8925c" style="width:1000px; height:460px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_79172abb53b94d9eaa81ef4654f8925c = echarts.init(
#                     document.getElementById('79172abb53b94d9eaa81ef4654f8925c'), 'white', {renderer: 'canvas'});
#                 var option_79172abb53b94d9eaa81ef4654f8925c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "Total Confirmed Cases",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "International",
#                     "value": 696.0
#                 },
#                 {
#                     "name": "Mali",
#                     "value": 2708.0
#                 },
#                 {
#                     "name": "Democratic Republic of Congo",
#                     "value": 9841.0
#                 },
#                 {
#                     "name": "Niger",
#                     "value": 1172.0
#                 },
#                 {
#                     "name": "Ghana",
#                     "value": 43622.0
#                 },
#                 {
#                     "name": "Nicaragua",
#                     "value": 4311.0
#                 },
#                 {
#                     "name": "Netherlands",
#                     "value": 67062.0
#                 },
#                 {
#                     "name": "Albania",
#                     "value": 8605.0
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 18762.0
#                 },
#                 {
#                     "name": "Norway",
#                     "value": 10323.0
#                 },
#                 {
#                     "name": "Nepal",
#                     "value": 32678.0
#                 },
#                 {
#                     "name": "Cote d'Ivoire",
#                     "value": 17506.0
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 1339.0
#                 },
#                 {
#                     "name": "Oman",
#                     "value": 84509.0
#                 },
#                 {
#                     "name": "China",
#                     "value": 89718.0
#                 },
#                 {
#                     "name": "Pakistan",
#                     "value": 293711.0
#                 },
#                 {
#                     "name": "Panama",
#                     "value": 87485.0
#                 },
#                 {
#                     "name": "Chile",
#                     "value": 399568.0
#                 },
#                 {
#                     "name": "Peru",
#                     "value": 600438.0
#                 },
#                 {
#                     "name": "New Caledonia",
#                     "value": 23.0
#                 },
#                 {
#                     "name": "Namibia",
#                     "value": 6030.0
#                 },
#                 {
#                     "name": "Congo",
#                     "value": 3850.0
#                 },
#                 {
#                     "name": "Afghanistan",
#                     "value": 38070.0
#                 },
#                 {
#                     "name": "Malta",
#                     "value": 1667.0
#                 },
#                 {
#                     "name": "Myanmar",
#                     "value": 474.0
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 3717.0
#                 },
#                 {
#                     "name": "Montenegro",
#                     "value": 4378.0
#                 },
#                 {
#                     "name": "Mongolia",
#                     "value": 298.0
#                 },
#                 {
#                     "name": "Costa Rica",
#                     "value": 34463.0
#                 },
#                 {
#                     "name": "Northern Mariana Islands",
#                     "value": 54.0
#                 },
#                 {
#                     "name": "Cape Verde",
#                     "value": 3532.0
#                 },
#                 {
#                     "name": "Malaysia",
#                     "value": 9274.0
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value": 3440.0
#                 },
#                 {
#                     "name": "Mauritania",
#                     "value": 6905.0
#                 },
#                 {
#                     "name": "Comoros",
#                     "value": 417.0
#                 },
#                 {
#                     "name": "Montserrat",
#                     "value": 13.0
#                 },
#                 {
#                     "name": "Mauritius",
#                     "value": 346.0
#                 },
#                 {
#                     "name": "Colombia",
#                     "value": 551696.0
#                 },
#                 {
#                     "name": "Malawi",
#                     "value": 5419.0
#                 },
#                 {
#                     "name": "Philippines",
#                     "value": 194252.0
#                 },
#                 {
#                     "name": "Switzerland",
#                     "value": 39959.0
#                 },
#                 {
#                     "name": "Papua New Guinea",
#                     "value": 401.0
#                 },
#                 {
#                     "name": "Belize",
#                     "value": 713.0
#                 },
#                 {
#                     "name": "Sierra Leone",
#                     "value": 1997.0
#                 },
#                 {
#                     "name": "Bolivia",
#                     "value": 110148.0
#                 },
#                 {
#                     "name": "El Salvador",
#                     "value": 24811.0
#                 },
#                 {
#                     "name": "San Marino",
#                     "value": 726.0
#                 },
#                 {
#                     "name": "Bermuda",
#                     "value": 168.0
#                 },
#                 {
#                     "name": "Somalia",
#                     "value": 3269.0
#                 },
#                 {
#                     "name": "Serbia",
#                     "value": 30714.0
#                 },
#                 {
#                     "name": "South Sudan",
#                     "value": 2504.0
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 3622861.0
#                 },
#                 {
#                     "name": "Sao Tome and Principe",
#                     "value": 892.0
#                 },
#                 {
#                     "name": "Belarus",
#                     "value": 70645.0
#                 },
#                 {
#                     "name": "Suriname",
#                     "value": 3632.0
#                 },
#                 {
#                     "name": "Slovakia",
#                     "

# %% [markdown]
# # Further analysis is beyond the scope of this project. The data file is rich and can potentially be used for pridictive modeling using machine learning algorithms.
